# %%
import torch
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import torch.nn as nn
import matplotlib.pyplot as plt
import numpy as np
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)
# Out:
# cuda

# %%
import kagglehub
path = kagglehub.dataset_download("tongpython/cat-and-dog")
print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/datasets/tongpython/cat-and-dog

# %%
import torchvision.transforms as transforms
size = 128
train_transform = transforms.Compose([
    transforms.Resize((size, size)),        # resize to model input size
    transforms.RandomHorizontalFlip(),    # horizontal flip augmentation
    transforms.RandomRotation(15),        # rotate ±15 degrees
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),
    transforms.ToTensor()                # convert PIL → tensor [0,1]
])

val_transform = transforms.Compose([
    transforms.Resize((size, size)),
    transforms.ToTensor(),
])

train_folder = path+'/training_set/training_set'
test_folder = path+'/test_set/test_set'

train_data = datasets.ImageFolder(train_folder,transform = train_transform)
test_data = datasets.ImageFolder(test_folder,transform = val_transform)

# %%
plt.figure(figsize = (2,2))
plt.imshow(train_data[800][0].permute(1,2,0))

# %%
#important HyperParameters
batch_size = 32
learning_rate=0.001
minimum_learning_rate=1e-4
epochs = 100

# %%
train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True,num_workers=2, pin_memory=True)
val_loader = DataLoader(test_data, batch_size=batch_size, shuffle=True, num_workers=2, pin_memory=True)

# %%
from torch.optim import Adam
from torch.optim.lr_scheduler import CosineAnnealingLR

class CNNModel(nn.Module):
    def __init__(self):
        super(CNNModel, self).__init__()
        # Feature extraction layers
        self.features = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True),
            nn.Conv2d(32, 32, kernel_size=3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2),
            nn.Dropout2d(0.1),

            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2),
            nn.Dropout2d(0.2),

            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.Conv2d(128, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2),
            nn.Dropout2d(0.3)
        )

        # Classification layers
        self.classifier = nn.Sequential(
            nn.AdaptiveAvgPool2d((4, 4)),
            nn.Flatten(),
            nn.Linear(128 * 4 * 4, 256),
            nn.BatchNorm1d(256),
            nn.ReLU(inplace=True),
            nn.Dropout(0.4),
            nn.Linear(256, 2)
        )

    def forward(self, x):
        x = self.features(x)
        x = self.classifier(x)
        return x

#1. Get the Model
model = CNNModel().to(device)
# 2. Define optimizer
optimizer = Adam(model.parameters(), lr=learning_rate)
# 3. Define LR scheduler
scheduler = CosineAnnealingLR(optimizer, T_max=epochs, eta_min=minimum_learning_rate)
# 4. Define loss function
criterion = nn.CrossEntropyLoss()

from torchsummary import summary
summary(model, input_size=(3,size,size));
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 32, 128, 128]             896
#        BatchNorm2d-2         [-1, 32, 128, 128]              64
#               ReLU-3         [-1, 32, 128, 128]               0
#             Conv2d-4         [-1, 32, 128, 128]           9,248
#        BatchNorm2d-5         [-1, 32, 128, 128]              64
#               ReLU-6         [-1, 32, 128, 128]               0
#          MaxPool2d-7           [-1, 32, 64, 64]               0
#          Dropout2d-8           [-1, 32, 64, 64]               0
#             Conv2d-9           [-1, 64, 64, 64]          18,496
#       BatchNorm2d-10           [-1, 64, 64, 64]             128
#              ReLU-11           [-1, 64, 64, 64]               0
#            Conv2d-12           [-1, 64, 64, 64]          36,928
#       BatchNorm2d-13           [-1, 64, 64, 64]             128
#              ReLU-14           [-1, 64, 64, 64]               0
#         MaxPool2d-15           [-1, 64, 32, 32]               0
#         Dropout2d-16           [-1, 64, 32, 32]               0
#            Conv2d-17          [-1, 128, 32, 32]          73,856
#       BatchNorm2d-18          [-1, 128, 32, 32]             256
#              ReLU-19          [-1, 128, 32, 32]               0
#            Conv2d-20          [-1, 128, 32, 32]         147,584
#       BatchNorm2d-21          [-1, 128, 32, 32]             256
#              ReLU-22          [-1, 128, 32, 32]               0
#         MaxPool2d-23          [-1, 128, 16, 16]               0
#         Dropout2d-24          [-1, 128, 16, 16]               0
# AdaptiveAvgPool2d-25            [-1, 128, 4, 4]               0
#           Flatten-26                 [-1, 2048]               0
#            Linear-27                  [-1, 256]         524,544
#       BatchNorm1d-28                  [-1, 256]             512
#              ReLU-29                  [-1, 256]               0
#           Dropout-30                  [-1, 256]               0
#            Linear-31                    [-1, 2]             514
# ================================================================
# Total params: 813,474
# Trainable params: 813,474
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.19
# Forward/backward pass size (MB): 45.54
# Params size (MB): 3.10
# Estimated Total Size (MB): 48.83
# ----------------------------------------------------------------

# %%
def train_epoch(model, loader, optimizer, criterion, device):
    model.train()
    total_loss = 0
    correct = 0
    total = 0
    for images, labels in loader:

        images = images.to(device)
        labels = labels.to(device)

        outputs = model(images)
        loss = criterion(outputs, labels)

        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

        total_loss += loss.item()

        # compute accuracy
        _, preds = torch.max(outputs, 1)
        correct += (preds == labels).sum().item()
        total += labels.size(0)

    train_loss = total_loss / len(loader)
    train_acc = correct / total

    return train_loss, train_acc

def validate_epoch(model, loader, criterion, device):

    model.eval()

    total_loss = 0
    correct = 0
    total = 0

    with torch.no_grad():
        for images, labels in loader:
            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)
            loss = criterion(outputs, labels)

            total_loss += loss.item()

            _, preds = torch.max(outputs, 1)
            correct += (preds == labels).sum().item()
            total += labels.size(0)

    val_loss = total_loss / len(loader)
    val_acc = correct / total

    return val_loss, val_acc

# %%
train_losses = []
train_accuracies = []
val_losses = []
val_accuracies = []

for epoch in range(epochs):
    print(f"----------------------------------------------------")
    print(f"Epoch {epoch+1}/{epochs}, LR: {optimizer.param_groups[0]['lr']:.6g}")

    train_loss, train_acc = train_epoch(model, train_loader, optimizer, criterion, device)
    val_loss, val_acc = validate_epoch(model, val_loader, criterion, device)
    scheduler.step()

    train_losses.append(train_loss)
    train_accuracies.append(train_acc)
    val_losses.append(val_loss)
    val_accuracies.append(val_acc)
    if (epoch+1)%20 == 0:
        torch.save(model.state_dict(),f'CatDogCNN{epoch+1}.pth')
        
    print(f"Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.4f}")
    print(f"Val Loss: {val_loss:.4f} | Val Acc: {val_acc:.4f}")
# Out:
# ----------------------------------------------------
# Epoch 1/100, LR: 0.001
# Train Loss: 0.6669 | Train Acc: 0.6237
# Val Loss: 0.6404 | Val Acc: 0.6263
# ----------------------------------------------------
# Epoch 2/100, LR: 0.000999778
# Train Loss: 0.6130 | Train Acc: 0.6647
# Val Loss: 0.5510 | Val Acc: 0.7133
# ----------------------------------------------------
# Epoch 3/100, LR: 0.000999112
# Train Loss: 0.5867 | Train Acc: 0.6869
# Val Loss: 0.6858 | Val Acc: 0.6456
# ----------------------------------------------------
# Epoch 4/100, LR: 0.000998003
# Train Loss: 0.5613 | Train Acc: 0.7053
# Val Loss: 0.5217 | Val Acc: 0.7395
# ----------------------------------------------------
# Epoch 5/100, LR: 0.000996452
# Train Loss: 0.5426 | Train Acc: 0.7196
# Val Loss: 0.4834 | Val Acc: 0.7657
# ----------------------------------------------------
# Epoch 6/100, LR: 0.00099446
# Train Loss: 0.5155 | Train Acc: 0.7418
# Val Loss: 0.4574 | Val Acc: 0.7785
# ----------------------------------------------------
# Epoch 7/100, LR: 0.000992029
# Train Loss: 0.5086 | Train Acc: 0.7550
# Val Loss: 0.4972 | Val Acc: 0.7583
# ----------------------------------------------------
# Epoch 8/100, LR: 0.000989163
# Train Loss: 0.4922 | Train Acc: 0.7629
# Val Loss: 0.4834 | Val Acc: 0.7662
# ----------------------------------------------------
# Epoch 9/100, LR: 0.000985862
# Train Loss: 0.4609 | Train Acc: 0.7819
# Val Loss: 0.4151 | Val Acc: 0.8003
# ----------------------------------------------------
# Epoch 10/100, LR: 0.000982132
# Train Loss: 0.4550 | Train Acc: 0.7889
# Val Loss: 0.3986 | Val Acc: 0.8220
# ----------------------------------------------------
# Epoch 11/100, LR: 0.000977975
# Train Loss: 0.4361 | Train Acc: 0.7980
# Val Loss: 0.4320 | Val Acc: 0.8008
# ----------------------------------------------------
# Epoch 12/100, LR: 0.000973396
# Train Loss: 0.4249 | Train Acc: 0.8046
# Val Loss: 0.3680 | Val Acc: 0.8309
# ----------------------------------------------------
# Epoch 13/100, LR: 0.000968399
# Train Loss: 0.4092 | Train Acc: 0.8127
# Val Loss: 0.4309 | Val Acc: 0.7968
# ----------------------------------------------------
# Epoch 14/100, LR: 0.00096299
# Train Loss: 0.3907 | Train Acc: 0.8229
# Val Loss: 0.3453 | Val Acc: 0.8522
# ----------------------------------------------------
# Epoch 15/100, LR: 0.000957172
# Train Loss: 0.3862 | Train Acc: 0.8254
# Val Loss: 0.3282 | Val Acc: 0.8527
# ----------------------------------------------------
# Epoch 16/100, LR: 0.000950953
# Train Loss: 0.3705 | Train Acc: 0.8360
# Val Loss: 0.3597 | Val Acc: 0.8458
# ----------------------------------------------------
# Epoch 17/100, LR: 0.000944338
# Train Loss: 0.3601 | Train Acc: 0.8437
# Val Loss: 0.3146 | Val Acc: 0.8616
# ----------------------------------------------------
# Epoch 18/100, LR: 0.000937334
# Train Loss: 0.3613 | Train Acc: 0.8391
# Val Loss: 0.3209 | Val Acc: 0.8547
# ----------------------------------------------------
# Epoch 19/100, LR: 0.000929948
# Train Loss: 0.3446 | Train Acc: 0.8477
# Val Loss: 0.2970 | Val Acc: 0.8720
# ----------------------------------------------------
# Epoch 20/100, LR: 0.000922186
# Train Loss: 0.3455 | Train Acc: 0.8502
# Val Loss: 0.2946 | Val Acc: 0.8735
# ----------------------------------------------------
# Epoch 21/100, LR: 0.000914058
# Train Loss: 0.3275 | Train Acc: 0.8587
# Val Loss: 0.2696 | Val Acc: 0.8888
# ----------------------------------------------------
# Epoch 22/100, LR: 0.00090557
# Train Loss: 0.3029 | Train Acc: 0.8691
# Val Loss: 0.2527 | Val Acc: 0.9001
# ----------------------------------------------------
# Epoch 23/100, LR: 0.000896731
# Train Loss: 0.3072 | Train Acc: 0.8632
# Val Loss: 0.2689 | Val Acc: 0.8838
# ----------------------------------------------------
# Epoch 24/100, LR: 0.00088755
# Train Loss: 0.2967 | Train Acc: 0.8751
# Val Loss: 0.3309 | Val Acc: 0.8562
# ----------------------------------------------------
# Epoch 25/100, LR: 0.000878036
# Train Loss: 0.2959 | Train Acc: 0.8752
# Val Loss: 0.2699 | Val Acc: 0.8863
# ----------------------------------------------------
# Epoch 26/100, LR: 0.000868198
# Train Loss: 0.2815 | Train Acc: 0.8758
# Val Loss: 0.2615 | Val Acc: 0.8932
# ----------------------------------------------------
# Epoch 27/100, LR: 0.000858046
# Train Loss: 0.2681 | Train Acc: 0.8878
# Val Loss: 0.2289 | Val Acc: 0.8972
# ----------------------------------------------------
# Epoch 28/100, LR: 0.00084759
# Train Loss: 0.2591 | Train Acc: 0.8891
# Val Loss: 0.2233 | Val Acc: 0.9125
# ----------------------------------------------------
# Epoch 29/100, LR: 0.000836841
# Train Loss: 0.2674 | Train Acc: 0.8846
# Val Loss: 0.2237 | Val Acc: 0.9135
# ----------------------------------------------------
# Epoch 30/100, LR: 0.000825808
# Train Loss: 0.2530 | Train Acc: 0.8982
# Val Loss: 0.2078 | Val Acc: 0.9110
# ----------------------------------------------------
# Epoch 31/100, LR: 0.000814503
# Train Loss: 0.2454 | Train Acc: 0.8996
# Val Loss: 0.2074 | Val Acc: 0.9155
# ----------------------------------------------------
# Epoch 32/100, LR: 0.000802938
# Train Loss: 0.2342 | Train Acc: 0.9023
# Val Loss: 0.2143 | Val Acc: 0.9110
# ----------------------------------------------------
# Epoch 33/100, LR: 0.000791122
# Train Loss: 0.2371 | Train Acc: 0.9007
# Val Loss: 0.2350 | Val Acc: 0.9046
# ----------------------------------------------------
# Epoch 34/100, LR: 0.000779069
# Train Loss: 0.2279 | Train Acc: 0.9082
# Val Loss: 0.2047 | Val Acc: 0.9150
# ----------------------------------------------------
# Epoch 35/100, LR: 0.000766789
# Train Loss: 0.2280 | Train Acc: 0.9026
# Val Loss: 0.2069 | Val Acc: 0.9155
# ----------------------------------------------------
# Epoch 36/100, LR: 0.000754296
# Train Loss: 0.2212 | Train Acc: 0.9094
# Val Loss: 0.1974 | Val Acc: 0.9254
# ----------------------------------------------------
# Epoch 37/100, LR: 0.000741601
# Train Loss: 0.2098 | Train Acc: 0.9132
# Val Loss: 0.1921 | Val Acc: 0.9140
# ----------------------------------------------------
# Epoch 38/100, LR: 0.000728717
# Train Loss: 0.2100 | Train Acc: 0.9153
# Val Loss: 0.2022 | Val Acc: 0.9165
# ----------------------------------------------------
# Epoch 39/100, LR: 0.000715656
# Train Loss: 0.2071 | Train Acc: 0.9128
# Val Loss: 0.1818 | Val Acc: 0.9249
# ----------------------------------------------------
# Epoch 40/100, LR: 0.000702432
# Train Loss: 0.1970 | Train Acc: 0.9184
# Val Loss: 0.1803 | Val Acc: 0.9263
# ----------------------------------------------------
# Epoch 41/100, LR: 0.000689058
# Train Loss: 0.1998 | Train Acc: 0.9162
# Val Loss: 0.1713 | Val Acc: 0.9328
# ----------------------------------------------------
# Epoch 42/100, LR: 0.000675546
# Train Loss: 0.2014 | Train Acc: 0.9162
# Val Loss: 0.1756 | Val Acc: 0.9318
# ----------------------------------------------------
# Epoch 43/100, LR: 0.00066191
# Train Loss: 0.1963 | Train Acc: 0.9228
# Val Loss: 0.1690 | Val Acc: 0.9348
# ----------------------------------------------------
# Epoch 44/100, LR: 0.000648164
# Train Loss: 0.1906 | Train Acc: 0.9222
# Val Loss: 0.1620 | Val Acc: 0.9338
# ----------------------------------------------------
# Epoch 45/100, LR: 0.000634322
# Train Loss: 0.1920 | Train Acc: 0.9258
# Val Loss: 0.1874 | Val Acc: 0.9224
# ----------------------------------------------------
# Epoch 46/100, LR: 0.000620396
# Train Loss: 0.1877 | Train Acc: 0.9239
# Val Loss: 0.1787 | Val Acc: 0.9298
# ----------------------------------------------------
# Epoch 47/100, LR: 0.0006064
# Train Loss: 0.1846 | Train Acc: 0.9193
# Val Loss: 0.1546 | Val Acc: 0.9407
# ----------------------------------------------------
# Epoch 48/100, LR: 0.000592349
# Train Loss: 0.1756 | Train Acc: 0.9290
# Val Loss: 0.1806 | Val Acc: 0.9214
# ----------------------------------------------------
# Epoch 49/100, LR: 0.000578256
# Train Loss: 0.1737 | Train Acc: 0.9313
# Val Loss: 0.1593 | Val Acc: 0.9333
# ----------------------------------------------------
# Epoch 50/100, LR: 0.000564135
# Train Loss: 0.1686 | Train Acc: 0.9344
# Val Loss: 0.1696 | Val Acc: 0.9303
# ----------------------------------------------------
# Epoch 51/100, LR: 0.00055
# Train Loss: 0.1659 | Train Acc: 0.9337
# Val Loss: 0.1538 | Val Acc: 0.9348
# ----------------------------------------------------
# Epoch 52/100, LR: 0.000535865
# Train Loss: 0.1649 | Train Acc: 0.9340
# Val Loss: 0.1631 | Val Acc: 0.9367
# ----------------------------------------------------
# Epoch 53/100, LR: 0.000521744
# Train Loss: 0.1610 | Train Acc: 0.9370
# Val Loss: 0.1541 | Val Acc: 0.9441
# ----------------------------------------------------
# Epoch 54/100, LR: 0.000507651
# Train Loss: 0.1657 | Train Acc: 0.9358
# Val Loss: 0.1447 | Val Acc: 0.9446
# ----------------------------------------------------
# Epoch 55/100, LR: 0.0004936
# Train Loss: 0.1625 | Train Acc: 0.9324
# Val Loss: 0.1516 | Val Acc: 0.9422
# ----------------------------------------------------
# Epoch 56/100, LR: 0.000479604
# Train Loss: 0.1555 | Train Acc: 0.9378
# Val Loss: 0.1471 | Val Acc: 0.9397
# ----------------------------------------------------
# Epoch 57/100, LR: 0.000465678
# Train Loss: 0.1505 | Train Acc: 0.9414
# Val Loss: 0.1840 | Val Acc: 0.9392
# ----------------------------------------------------
# Epoch 58/100, LR: 0.000451836
# Train Loss: 0.1531 | Train Acc: 0.9372
# Val Loss: 0.1432 | Val Acc: 0.9417
# ----------------------------------------------------
# Epoch 59/100, LR: 0.00043809
# Train Loss: 0.1532 | Train Acc: 0.9378
# Val Loss: 0.1461 | Val Acc: 0.9417
# ----------------------------------------------------
# Epoch 60/100, LR: 0.000424454
# Train Loss: 0.1457 | Train Acc: 0.9432
# Val Loss: 0.1406 | Val Acc: 0.9422
# ----------------------------------------------------
# Epoch 61/100, LR: 0.000410942
# Train Loss: 0.1464 | Train Acc: 0.9423
# Val Loss: 0.1513 | Val Acc: 0.9412
# ----------------------------------------------------
# Epoch 62/100, LR: 0.000397568
# Train Loss: 0.1396 | Train Acc: 0.9437
# Val Loss: 0.1474 | Val Acc: 0.9466
# ----------------------------------------------------
# Epoch 63/100, LR: 0.000384344
# Train Loss: 0.1464 | Train Acc: 0.9414
# Val Loss: 0.1397 | Val Acc: 0.9466
# ----------------------------------------------------
# Epoch 64/100, LR: 0.000371283
# Train Loss: 0.1273 | Train Acc: 0.9483
# Val Loss: 0.1488 | Val Acc: 0.9417
# ----------------------------------------------------
# Epoch 65/100, LR: 0.000358399
# Train Loss: 0.1391 | Train Acc: 0.9452
# Val Loss: 0.1369 | Val Acc: 0.9471
# ----------------------------------------------------
# Epoch 66/100, LR: 0.000345704
# Train Loss: 0.1346 | Train Acc: 0.9524
# Val Loss: 0.1431 | Val Acc: 0.9432
# ----------------------------------------------------
# Epoch 67/100, LR: 0.000333211
# Train Loss: 0.1353 | Train Acc: 0.9448
# Val Loss: 0.1690 | Val Acc: 0.9382
# ----------------------------------------------------
# Epoch 68/100, LR: 0.000320931
# Train Loss: 0.1388 | Train Acc: 0.9455
# Val Loss: 0.1570 | Val Acc: 0.9451
# ----------------------------------------------------
# Epoch 69/100, LR: 0.000308878
# Train Loss: 0.1367 | Train Acc: 0.9468
# Val Loss: 0.1427 | Val Acc: 0.9461
# ----------------------------------------------------
# Epoch 70/100, LR: 0.000297062
# Train Loss: 0.1284 | Train Acc: 0.9505
# Val Loss: 0.1351 | Val Acc: 0.9466
# ----------------------------------------------------
# Epoch 71/100, LR: 0.000285497
# Train Loss: 0.1170 | Train Acc: 0.9549
# Val Loss: 0.1490 | Val Acc: 0.9476
# ----------------------------------------------------
# Epoch 72/100, LR: 0.000274192
# Train Loss: 0.1226 | Train Acc: 0.9510
# Val Loss: 0.1346 | Val Acc: 0.9496
# ----------------------------------------------------
# Epoch 73/100, LR: 0.000263159
# Train Loss: 0.1283 | Train Acc: 0.9519
# Val Loss: 0.1360 | Val Acc: 0.9501
# ----------------------------------------------------
# Epoch 74/100, LR: 0.00025241
# Train Loss: 0.1218 | Train Acc: 0.9497
# Val Loss: 0.1410 | Val Acc: 0.9496
# ----------------------------------------------------
# Epoch 75/100, LR: 0.000241954
# Train Loss: 0.1137 | Train Acc: 0.9570
# Val Loss: 0.1394 | Val Acc: 0.9461
# ----------------------------------------------------
# Epoch 76/100, LR: 0.000231802
# Train Loss: 0.1180 | Train Acc: 0.9529
# Val Loss: 0.1379 | Val Acc: 0.9486
# ----------------------------------------------------
# Epoch 77/100, LR: 0.000221964
# Train Loss: 0.1207 | Train Acc: 0.9530
# Val Loss: 0.1376 | Val Acc: 0.9491
# ----------------------------------------------------
# Epoch 78/100, LR: 0.00021245
# Train Loss: 0.1188 | Train Acc: 0.9534
# Val Loss: 0.1336 | Val Acc: 0.9466
# ----------------------------------------------------
# Epoch 79/100, LR: 0.000203269
# Train Loss: 0.1179 | Train Acc: 0.9535
# Val Loss: 0.1262 | Val Acc: 0.9516
# ----------------------------------------------------
# Epoch 80/100, LR: 0.00019443
# Train Loss: 0.1157 | Train Acc: 0.9519
# Val Loss: 0.1295 | Val Acc: 0.9516
# ----------------------------------------------------
# Epoch 81/100, LR: 0.000185942
# Train Loss: 0.1067 | Train Acc: 0.9565
# Val Loss: 0.1420 | Val Acc: 0.9491
# ----------------------------------------------------
# Epoch 82/100, LR: 0.000177814
# Train Loss: 0.1132 | Train Acc: 0.9574
# Val Loss: 0.1366 | Val Acc: 0.9496
# ----------------------------------------------------
# Epoch 83/100, LR: 0.000170052
# Train Loss: 0.1065 | Train Acc: 0.9601
# Val Loss: 0.1282 | Val Acc: 0.9501
# ----------------------------------------------------
# Epoch 84/100, LR: 0.000162666
# Train Loss: 0.1155 | Train Acc: 0.9540
# Val Loss: 0.1457 | Val Acc: 0.9481
# ----------------------------------------------------
# Epoch 85/100, LR: 0.000155662
# Train Loss: 0.1130 | Train Acc: 0.9570
# Val Loss: 0.1406 | Val Acc: 0.9501
# ----------------------------------------------------
# Epoch 86/100, LR: 0.000149047
# Train Loss: 0.1168 | Train Acc: 0.9548
# Val Loss: 0.1314 | Val Acc: 0.9471
# ----------------------------------------------------
# Epoch 87/100, LR: 0.000142828
# Train Loss: 0.1010 | Train Acc: 0.9605
# Val Loss: 0.1369 | Val Acc: 0.9506
# ----------------------------------------------------
# Epoch 88/100, LR: 0.00013701
# Train Loss: 0.1124 | Train Acc: 0.9575
# Val Loss: 0.1648 | Val Acc: 0.9382
# ----------------------------------------------------
# Epoch 89/100, LR: 0.000131601
# Train Loss: 0.1036 | Train Acc: 0.9601
# Val Loss: 0.1388 | Val Acc: 0.9521
# ----------------------------------------------------
# Epoch 90/100, LR: 0.000126604
# Train Loss: 0.1085 | Train Acc: 0.9577
# Val Loss: 0.1364 | Val Acc: 0.9516
# ----------------------------------------------------
# Epoch 91/100, LR: 0.000122025
# Train Loss: 0.0999 | Train Acc: 0.9616
# Val Loss: 0.1375 | Val Acc: 0.9501
# ----------------------------------------------------
# Epoch 92/100, LR: 0.000117868
# Train Loss: 0.1054 | Train Acc: 0.9631
# Val Loss: 0.1421 | Val Acc: 0.9471
# ----------------------------------------------------
# Epoch 93/100, LR: 0.000114138
# Train Loss: 0.0971 | Train Acc: 0.9644
# Val Loss: 0.1308 | Val Acc: 0.9525
# ----------------------------------------------------
# Epoch 94/100, LR: 0.000110837
# Train Loss: 0.1019 | Train Acc: 0.9613
# Val Loss: 0.1298 | Val Acc: 0.9530
# ----------------------------------------------------
# Epoch 95/100, LR: 0.000107971
# Train Loss: 0.0991 | Train Acc: 0.9604
# Val Loss: 0.1350 | Val Acc: 0.9506
# ----------------------------------------------------
# Epoch 96/100, LR: 0.00010554
# Train Loss: 0.0989 | Train Acc: 0.9618
# Val Loss: 0.1351 | Val Acc: 0.9535
# ----------------------------------------------------
# Epoch 97/100, LR: 0.000103548
# Train Loss: 0.0972 | Train Acc: 0.9614
# Val Loss: 0.1324 | Val Acc: 0.9535
# ----------------------------------------------------
# Epoch 98/100, LR: 0.000101997
# Train Loss: 0.0995 | Train Acc: 0.9590
# Val Loss: 0.1316 | Val Acc: 0.9530
# ----------------------------------------------------
# Epoch 99/100, LR: 0.000100888
# Train Loss: 0.0984 | Train Acc: 0.9616
# Val Loss: 0.1275 | Val Acc: 0.9545
# ----------------------------------------------------
# Epoch 100/100, LR: 0.000100222
# Train Loss: 0.0993 | Train Acc: 0.9616
# Val Loss: 0.1335 | Val Acc: 0.9540

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import matplotlib.gridspec as gridspec
import numpy as np

BLUE   = "#3266ad"
ORANGE = "#e07b39"
GRAY   = "#88877f"
BLACK  = "#000000"

plt.rcParams.update({
    "font.family": "sans-serif",
    "axes.spines.top": False,
    "axes.spines.right": False,
    "axes.edgecolor": "#d3d1c7",
    "axes.linewidth": 0.8,
    "axes.grid": True,
    "grid.color": "#d3d1c7",
    "grid.linewidth": 0.5,
    "grid.linestyle": "--",
    "xtick.color": BLACK,
    "ytick.color": BLACK,
    "xtick.labelsize": 10,
    "ytick.labelsize": 10,
})

epochs_number = np.arange(1, epochs+1)
fig = plt.figure(figsize=(20, 4))
gs  = gridspec.GridSpec(1, 2, figure=fig, wspace=0.2)

# ── Accuracy ──────────────────────────────────────────────────────────────────
ax1 = fig.add_subplot(gs[0])
ax1.plot(epochs_number, train_accuracies, color=BLUE,   lw=2,   label="Train",      marker="o", ms=4, mew=1.5, mec="white")
ax1.plot(epochs_number, val_accuracies,   color=ORANGE, lw=2,   label="Validation", marker="o", ms=4, mew=1.5, mec="white", linestyle="-")
ax1.xaxis.set_major_locator(mticker.MultipleLocator(1))
ax1.yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f"{x*100:.0f}%"))
ax1.set_xlabel("Epoch", color=BLACK, fontsize=11)
ax1.set_ylabel("Accuracy", color=BLACK, fontsize=11)
ax1.set_title("Accuracy", fontsize=12, fontweight="medium", color="#2c2c2a", pad=10)
ax1.legend(frameon=False, fontsize=10, labelcolor=BLACK)

# ── Loss ──────────────────────────────────────────────────────────────────────
ax2 = fig.add_subplot(gs[1])
ax2.plot(epochs_number, train_losses, color=BLUE,   lw=2, label="Train",      marker="o", ms=4, mew=1.5, mec="white")
ax2.plot(epochs_number, val_losses,   color=ORANGE, lw=2, label="Validation", marker="o", ms=4, mew=1.5, mec="white", linestyle="-")
ax2.xaxis.set_major_locator(mticker.MultipleLocator(1))
ax2.yaxis.set_major_locator(mticker.MultipleLocator(0.05))
ax2.set_xlabel("Epoch", color=BLACK, fontsize=11)
ax2.set_ylabel("Loss",  color=BLACK, fontsize=11)
ax2.set_title("Loss", fontsize=12, fontweight="medium", color="#2c2c2a", pad=10)
ax2.legend(frameon=False, fontsize=10, labelcolor=BLACK)

fig.suptitle("Training diagnostics", fontsize=14, fontweight="medium", color="#2c2c2a", y=1.02)
plt.savefig("training_curves.pdf", bbox_inches="tight", dpi=150)
plt.show()

# %%
model.eval()
with torch.no_grad():
  ix = torch.randint(0,len(test_data),())
  img = test_data[ix][0].unsqueeze(0).to(device)
  np_output = model(img).cpu().detach().numpy()
  pred = np.exp(np_output)/np.sum(np.exp(np_output))
  plt.figure(figsize=(2,2))
  plt.imshow(img.squeeze(0).permute(1,2,0).cpu().detach().numpy())
  plt.title(train_data.classes[pred[0].argmax()])
  plt.show()

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

class_names = test_data.classes  # from ImageFolder

model.eval()
misclassified = []
all_preds = []
all_labels = []

with torch.no_grad():
    for images, labels in val_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, preds = torch.max(outputs, 1)

        # Save all predictions and labels for confusion matrix
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

        # Store misclassified images
        for img, true, pred in zip(images, labels, preds):
            if true != pred:
                misclassified.append((img.cpu(), true.cpu(), pred.cpu()))

# %%
print(f"Total misclassified samples: {len(misclassified)}")
num_rows = 5
num_cols = 8
num_to_show = num_rows * num_cols
num_to_show = min(num_to_show, len(misclassified))

fig, axes = plt.subplots(num_rows, num_cols, figsize=(num_cols*2, num_rows*2))
axes = axes.flatten()  # flatten for easy iteration

for idx in range(num_to_show):
    img, true, pred = misclassified[idx]
    img = img.permute(1, 2, 0)  # CxHxW -> HxWxC
    axes[idx].imshow(img)
    axes[idx].set_title(f"True: {class_names[true]}\nPred: {class_names[pred]}")
    axes[idx].axis('off')

# Turn off any unused subplots
for idx in range(num_to_show, len(axes)):
    axes[idx].axis('off')
plt.savefig("Misclassified Images.pdf", bbox_inches="tight", dpi=150)
plt.tight_layout()
plt.show()
# Out:
# Total misclassified samples: 93

# %%
cm = confusion_matrix(all_labels, all_preds)
plt.figure(figsize=(4, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=train_data.classes, yticklabels=train_data.classes)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.savefig('Confusion Matrix', bbox_inches="tight", dpi=150)
plt.show()

# %%
torch.save(model.state_dict(),'CatDogCNN.pth')

# %%
LoadTrainedModel = True
if LoadTrainedModel:
    saved_model = CNNModel().to(device)
    
    saved_model.load_state_dict(torch.load('/kaggle/working/CatDogCNN.pth'))
    saved_model.eval()
    print("Saved Model Loaded")
    #summary(saved_model, input_size=(3,size,size));
# Out:
# Saved Model Loaded

# %%
# !pip install -qq grad-cam
from pytorch_grad_cam import GradCAM
from pytorch_grad_cam.utils.image import show_cam_on_image
import matplotlib.pyplot as plt

rgb_img = test_data[999][0].unsqueeze(0)

# Last conv layer in your CNN
target_layers = [model.features[19]]

# Create GradCAM object
cam = GradCAM(model=model, target_layers=target_layers)

# Generate CAM
grayscale_cam = cam(input_tensor=rgb_img, targets=None)  # None = highest scoring class
grayscale_cam = grayscale_cam[0, :]  # batch size = 1

# Convert tensor to HWC format for overlay
rgb_img_np = rgb_img[0].permute(1,2,0).cpu().numpy()
rgb_img_np = (rgb_img_np - rgb_img_np.min()) / (rgb_img_np.max() - rgb_img_np.min())  # normalize 0-1

# Overlay Grad-CAM
visualization = show_cam_on_image(rgb_img_np, grayscale_cam, use_rgb=True)

plt.figure(figsize=(5,5))
plt.imshow(visualization)
plt.axis('off')
plt.savefig("GRAD_CAM.pdf", bbox_inches="tight", dpi=150)
plt.show()
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 71.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for grad-cam (pyproject.toml) ... done
